# %%
import pandas as pd

df=pd.read_csv(r"C:\Crime\crime_dataset_india.csv")

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Report Number       40160 non-null  int64
#  1   Date Reported       40160 non-null  object
#  2   Date of Occurrence  40160 non-null  object
#  3   Time of Occurrence  40160 non-null  object
#  4   City                40160 non-null  object
#  5   Crime Code          40160 non-null  int64
#  6   Crime Description   40160 non-null  object
#  7   Victim Age          40160 non-null  int64
#  8   Victim Gender       40160 non-null  object
#  9   Weapon Used         34370 non-null  object
#  10  Crime Domain        40160 non-null  object
#  11  Police Deployed     40160 non-null  int64
#  12  Case Closed         40160 non-null  object
#  13  Date Case Closed    20062 non-null  object
# dtypes: int64(4), object(10)
# memory usage: 4.3+ MB

# %%
df.describe()
# Out:
#        Report Number    Crime Code   Victim Age  Police Deployed
# count   40160.000000  40160.000000  40160.00000     40160.000000
# mean    20080.500000    349.360259     44.49126        10.006250
# std     11593.337742    144.169205     20.22555         5.467951
# min         1.000000    100.000000     10.00000         1.000000
# 25%     10040.750000    225.000000     27.00000         5.000000
# 50%     20080.500000    349.000000     44.00000        10.000000
# 75%     30120.250000    474.000000     62.00000        15.000000
# max     40160.000000    599.000000     79.00000        19.000000

# %%
df.isnull().sum()
# Out:
# Report Number             0
# Date Reported             0
# Date of Occurrence        0
# Time of Occurrence        0
# City                      0
# Crime Code                0
# Crime Description         0
# Victim Age                0
# Victim Gender             0
# Weapon Used            5790
# Crime Domain              0
# Police Deployed           0
# Case Closed               0
# Date Case Closed      20098
# dtype: int64

# %%
df['Weapon Used'].fillna(method='bfill',inplace=True)
df['Weapon Used'].isnull().sum()
# Out:
# C:\Users\great\AppData\Local\Temp\ipykernel_8520\3222316400.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weapon Used'].fillna(method='bfill',inplace=True)
# C:\Users\great\AppData\Local\Temp\ipykernel_8520\3222316400.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Weapon Used'].fillna(method='bfill',inplace=True)
# np.int64(0)

# %%
df['Date Case Closed'] = pd.to_datetime(df['Date Case Closed'],errors="coerce")
df['Date Case Closed'].info()
# Out:
# C:\Users\great\AppData\Local\Temp\ipykernel_8520\4174494393.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date Case Closed'] = pd.to_datetime(df['Date Case Closed'],errors="coerce")
# <class 'pandas.core.series.Series'>
# RangeIndex: 40160 entries, 0 to 40159
# Series name: Date Case Closed
# Non-Null Count  Dtype
# --------------  -----
# 20062 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 313.9 KB

# %%
df
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00   07-31-2024 06:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
df['Date Reported'] = pd.to_datetime(df['Date Reported'],errors="coerce")
df['Date Case Closed'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40160 entries, 0 to 40159
# Series name: Date Case Closed
# Non-Null Count  Dtype
# --------------  -----
# 20062 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 313.9 KB

# %%
df['Time of Occurrence'] = pd.to_datetime(df['Time of Occurrence'],errors="coerce")
df['Time of Occurrence'].isnull().sum()
# Out:
# np.int64(24332)

# %%
df['Date of Occurrence'] = pd.to_datetime(df['Date of Occurrence'],errors="coerce")
df['Date of Occurrence'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40160 entries, 0 to 40159
# Series name: Date of Occurrence
# Non-Null Count  Dtype
# --------------  -----
# 40160 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 313.9 KB

# %%
df['Time of Occurrence']
# Out:
# 0       2020-01-01 01:11:00
# 1       2020-01-01 06:26:00
# 2       2020-01-01 14:30:00
# 3       2020-01-01 14:46:00
# 4       2020-01-01 16:51:00
#                 ...
# 40155                   NaT
# 40156                   NaT
# 40157                   NaT
# 40158                   NaT
# 40159                   NaT
# Name: Time of Occurrence, Length: 40160, dtype: datetime64[ns]

# %%
df['Time'] = df['Time of Occurrence'].dt.time
df['Time']
# Out:
# 0        01:11:00
# 1        06:26:00
# 2        14:30:00
# 3        14:46:00
# 4        16:51:00
#            ...
# 40155         NaT
# 40156         NaT
# 40157         NaT
# 40158         NaT
# 40159         NaT
# Name: Time, Length: 40160, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Report Number       40160 non-null  int64
#  1   Date Reported       15874 non-null  datetime64[ns]
#  2   Date of Occurrence  40160 non-null  datetime64[ns]
#  3   Time of Occurrence  15828 non-null  datetime64[ns]
#  4   City                40160 non-null  object
#  5   Crime Code          40160 non-null  int64
#  6   Crime Description   40160 non-null  object
#  7   Victim Age          40160 non-null  int64
#  8   Victim Gender       40160 non-null  object
#  9   Weapon Used         40160 non-null  object
#  10  Crime Domain        40160 non-null  object
#  11  Police Deployed     40160 non-null  int64
#  12  Case Closed         40160 non-null  object
#  13  Date Case Closed    20062 non-null  datetime64[ns]
#  14  Time                15828 non-null  object
# ...

# %%
df
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 0                  1 2020-02-01 00:00:00 2020-01-01 00:00:00
# 1                  2 2020-01-01 19:00:00 2020-01-01 01:00:00
# 2                  3 2020-02-01 05:00:00 2020-01-01 02:00:00
# 3                  4 2020-01-01 05:00:00 2020-01-01 03:00:00
# 4                  5 2020-01-01 21:00:00 2020-01-01 04:00:00
# ...              ...                 ...                 ...
# 40155          40156 2024-01-08 16:00:00 2024-07-31 03:00:00
# 40156          40157                 NaT 2024-07-31 04:00:00
# 40157          40158 2024-02-08 03:00:00 2024-07-31 05:00:00
# 40158          40159 2024-01-08 19:00:00 2024-07-31 06:00:00
# 40159          40160                 NaT 2024-07-31 07:00:00
#
#        Time of Occurrence       City  Crime Code   Crime Description  \
# 0     2020-01-01 01:11:00  Ahmedabad         576      IDENTITY THEFT
# 1     2020-01-01 06:26:00    Chennai         128            HOMICIDE
# ...

# %% [markdown]
# # EDA -- Expolatory Data Analysis

# %%
df['Report Number'].count()
# Out:
# np.int64(40160)

# %%
df['City'].value_counts()
# Out:
# City
# Delhi            5400
# Mumbai           4415
# Bangalore        3588
# Hyderabad        2881
# Kolkata          2518
# Chennai          2493
# Pune             2212
# Ahmedabad        1817
# Jaipur           1479
# Lucknow          1456
# Kanpur           1112
# Surat            1111
# Nagpur           1053
# Agra              764
# Ludhiana          761
# Visakhapatnam     728
# Thane             706
# Ghaziabad         704
# Indore            699
# Patna             695
# Bhopal            690
# Meerut            395
# Srinagar          371
# Nashik            366
# Vasai             362
# Varanasi          355
# Kalyan            355
# Faridabad         354
# Rajkot            320
# Name: count, dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Ahmedabad', 'Chennai', 'Ludhiana', 'Pune', 'Delhi', 'Mumbai',
#        'Surat', 'Visakhapatnam', 'Bangalore', 'Kolkata', 'Ghaziabad',
#        'Hyderabad', 'Jaipur', 'Lucknow', 'Bhopal', 'Patna', 'Kanpur',
#        'Varanasi', 'Nagpur', 'Meerut', 'Thane', 'Indore', 'Rajkot',
#        'Vasai', 'Agra', 'Kalyan', 'Nashik', 'Srinagar', 'Faridabad'],
#       dtype=object)

# %%
df['City'].value_counts().head(1)
# Out:
# City
# Delhi    5400
# Name: count, dtype: int64

# %%
df['City'].value_counts().tail(1)
# Out:
# City
# Rajkot    320
# Name: count, dtype: int64

# %%
df['Crime Domain'].value_counts()
# Out:
# Crime Domain
# Other Crime         22948
# Violent Crime       11472
# Fire Accident        3825
# Traffic Fatality     1915
# Name: count, dtype: int64

# %%
df['Crime Description'].value_counts()
# Out:
# Crime Description
# BURGLARY               1980
# VANDALISM              1975
# FRAUD                  1965
# DOMESTIC VIOLENCE      1932
# FIREARM OFFENSE        1931
# ROBBERY                1928
# KIDNAPPING             1920
# IDENTITY THEFT         1918
# SEXUAL ASSAULT         1917
# ASSAULT                1915
# TRAFFIC VIOLATION      1915
# PUBLIC INTOXICATION    1912
# HOMICIDE               1909
# CYBERCRIME             1899
# ILLEGAL POSSESSION     1895
# ARSON                  1894
# DRUG OFFENSE           1890
# EXTORTION              1873
# COUNTERFEITING         1871
# VEHICLE - STOLEN       1862
# SHOPLIFTING            1859
# Name: count, dtype: int64

# %%
df['Victim Gender'].value_counts()
# Out:
# Victim Gender
# F    22423
# M    13405
# X     4332
# Name: count, dtype: int64

# %%
df['Case Closed'].value_counts()
# Out:
# Case Closed
# No     20098
# Yes    20062
# Name: count, dtype: int64

# %%
df['Police Deployed'].mean()
# Out:
# np.float64(10.00625)

# %%
df.groupby('City')['Victim Age'].mean()
# Out:
# City
# Agra             43.691099
# Ahmedabad        44.319207
# Bangalore        44.658584
# Bhopal           44.198551
# Chennai          44.061372
# Delhi            44.225370
# Faridabad        45.867232
# Ghaziabad        44.654830
# Hyderabad        44.190212
# Indore           43.811159
# Jaipur           44.883029
# Kalyan           45.214085
# Kanpur           44.130396
# Kolkata          44.720016
# Lucknow          44.794643
# Ludhiana         44.839685
# Meerut           44.987342
# Mumbai           44.326614
# Nagpur           44.523267
# Nashik           45.918033
# Patna            44.752518
# Pune             44.968807
# Rajkot           43.693750
# Srinagar         43.382749
# Surat            44.806481
# Thane            45.773371
# Varanasi         44.526761
# Vasai            45.433702
# Visakhapatnam    44.285714
# Name: Victim Age, dtype: float64

# %%
df.groupby('City')['Victim Age'].max()
# Out:
# City
# Agra             79
# Ahmedabad        79
# Bangalore        79
# Bhopal           79
# Chennai          79
# Delhi            79
# Faridabad        79
# Ghaziabad        79
# Hyderabad        79
# Indore           79
# Jaipur           79
# Kalyan           79
# Kanpur           79
# Kolkata          79
# Lucknow          79
# Ludhiana         79
# Meerut           79
# Mumbai           79
# Nagpur           79
# Nashik           79
# Patna            79
# Pune             79
# Rajkot           79
# Srinagar         79
# Surat            79
# Thane            79
# Varanasi         79
# Vasai            79
# Visakhapatnam    79
# Name: Victim Age, dtype: int64

# %%
df.groupby('City')['Victim Age'].min()
# Out:
# City
# Agra             10
# Ahmedabad        10
# Bangalore        10
# Bhopal           10
# Chennai          10
# Delhi            10
# Faridabad        10
# Ghaziabad        10
# Hyderabad        10
# Indore           10
# Jaipur           10
# Kalyan           10
# Kanpur           10
# Kolkata          10
# Lucknow          10
# Ludhiana         10
# Meerut           10
# Mumbai           10
# Nagpur           10
# Nashik           10
# Patna            10
# Pune             10
# Rajkot           10
# Srinagar         10
# Surat            10
# Thane            10
# Varanasi         10
# Vasai            10
# Visakhapatnam    10
# Name: Victim Age, dtype: int64

# %%
df.groupby('Crime Domain')['Police Deployed'].mean()
# Out:
# Crime Domain
# Fire Accident        9.965752
# Other Crime         10.015906
# Traffic Fatality    10.044386
# Violent Crime        9.994073
# Name: Police Deployed, dtype: float64

# %%
df.groupby("Weapon Used")['Report Number'].mean()
# Out:
# Weapon Used
# Blunt Object    20263.982375
# Explosives      19962.784161
# Firearm         19930.481707
# Knife           20158.516552
# Other           20022.645351
# Poison          20138.415293
# Name: Report Number, dtype: float64

# %%
df.groupby('Victim Gender')['Victim Age'].mean()
# Out:
# Victim Gender
# F    44.268474
# M    44.543230
# X    45.483610
# Name: Victim Age, dtype: float64

# %%
df.groupby('Crime Description')['Victim Age'].mean()
# Out:
# Crime Description
# ARSON                  44.407075
# ASSAULT                43.555091
# BURGLARY               44.069192
# COUNTERFEITING         44.801176
# CYBERCRIME             44.013165
# DOMESTIC VIOLENCE      44.589545
# DRUG OFFENSE           44.102646
# EXTORTION              45.698345
# FIREARM OFFENSE        44.130502
# FRAUD                  44.246310
# HOMICIDE               44.374542
# IDENTITY THEFT         45.039625
# ILLEGAL POSSESSION     45.361478
# KIDNAPPING             44.029688
# PUBLIC INTOXICATION    44.265167
# ROBBERY                44.405083
# SEXUAL ASSAULT         44.199791
# SHOPLIFTING            44.947283
# TRAFFIC VIOLATION      43.865274
# VANDALISM              45.597975
# VEHICLE - STOLEN       44.656821
# Name: Victim Age, dtype: float64

# %%
df.groupby('City')['Weapon Used'].value_counts()
# Out:
# City           Weapon Used
# Agra           Firearm         142
#                Poison          136
#                Blunt Object    125
#                Knife           122
#                Other           121
#                               ...
# Visakhapatnam  Explosives      126
#                Knife           118
#                Poison          118
#                Firearm         117
#                Other           110
# Name: count, Length: 174, dtype: int64

# %%
df.groupby('Crime Description')['Weapon Used'].value_counts()
# Out:
# Crime Description  Weapon Used
# ARSON              Blunt Object    328
#                    Other           328
#                    Knife           321
#                    Poison          320
#                    Explosives      303
#                                   ...
# VEHICLE - STOLEN   Explosives      315
#                    Other           307
#                    Firearm         305
#                    Knife           299
#                    Blunt Object    292
# Name: count, Length: 126, dtype: int64

# %%
df.groupby('Victim Gender')['Victim Age'].mean()
# Out:
# Victim Gender
# F    44.268474
# M    44.543230
# X    45.483610
# Name: Victim Age, dtype: float64

# %%
df.groupby('Crime Description')['Victim Age'].mean()
# Out:
# Crime Description
# ARSON                  44.407075
# ASSAULT                43.555091
# BURGLARY               44.069192
# COUNTERFEITING         44.801176
# CYBERCRIME             44.013165
# DOMESTIC VIOLENCE      44.589545
# DRUG OFFENSE           44.102646
# EXTORTION              45.698345
# FIREARM OFFENSE        44.130502
# FRAUD                  44.246310
# HOMICIDE               44.374542
# IDENTITY THEFT         45.039625
# ILLEGAL POSSESSION     45.361478
# KIDNAPPING             44.029688
# PUBLIC INTOXICATION    44.265167
# ROBBERY                44.405083
# SEXUAL ASSAULT         44.199791
# SHOPLIFTING            44.947283
# TRAFFIC VIOLATION      43.865274
# VANDALISM              45.597975
# VEHICLE - STOLEN       44.656821
# Name: Victim Age, dtype: float64

# %%
g= df.groupby('City')['Crime Description'].value_counts()
g
# Out:
# City           Crime Description
# Agra           ASSAULT                47
#                ARSON                  43
#                PUBLIC INTOXICATION    43
#                COUNTERFEITING         40
#                FIREARM OFFENSE        40
#                                       ..
# Visakhapatnam  ROBBERY                30
#                EXTORTION              29
#                SHOPLIFTING            27
#                PUBLIC INTOXICATION    26
#                COUNTERFEITING         21
# Name: count, Length: 609, dtype: int64

# %%
g.to_csv(r"C:\Users\great\OneDrive\Desktop\gggg.csv")

# %%
df['Crime Description'].value_counts().head(10)
# Out:
# Crime Description
# BURGLARY             1980
# VANDALISM            1975
# FRAUD                1965
# DOMESTIC VIOLENCE    1932
# FIREARM OFFENSE      1931
# ROBBERY              1928
# KIDNAPPING           1920
# IDENTITY THEFT       1918
# SEXUAL ASSAULT       1917
# ASSAULT              1915
# Name: count, dtype: int64

# %%
df[df['Case Closed']=="Yes"]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 3                  4 2020-01-01 05:00:00 2020-01-01 03:00:00
# 4                  5 2020-01-01 21:00:00 2020-01-01 04:00:00
# 5                  6 2020-02-01 03:00:00 2020-01-01 05:00:00
# 6                  7 2020-01-01 16:00:00 2020-01-01 06:00:00
# 10                11 2020-02-01 13:00:00 2020-01-01 10:00:00
# ...              ...                 ...                 ...
# 40149          40150                 NaT 2024-07-30 21:00:00
# 40151          40152 2024-01-08 00:00:00 2024-07-30 23:00:00
# 40153          40154                 NaT 2024-07-31 01:00:00
# 40156          40157                 NaT 2024-07-31 04:00:00
# 40159          40160                 NaT 2024-07-31 07:00:00
#
#        Time of Occurrence     City  Crime Code    Crime Description  \
# 3     2020-01-01 14:46:00     Pune         170             BURGLARY
# 4     2020-01-01 16:51:00     Pune         421            VANDALISM
# ...

# %%
df[df['Case Closed']=="No"]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 0                  1 2020-02-01 00:00:00 2020-01-01 00:00:00
# 1                  2 2020-01-01 19:00:00 2020-01-01 01:00:00
# 2                  3 2020-02-01 05:00:00 2020-01-01 02:00:00
# 7                  8 2020-02-01 10:00:00 2020-01-01 07:00:00
# 8                  9 2020-04-01 03:00:00 2020-01-01 08:00:00
# ...              ...                 ...                 ...
# 40152          40153 2024-02-08 11:00:00 2024-07-31 00:00:00
# 40154          40155 2024-01-08 11:00:00 2024-07-31 02:00:00
# 40155          40156 2024-01-08 16:00:00 2024-07-31 03:00:00
# 40157          40158 2024-02-08 03:00:00 2024-07-31 05:00:00
# 40158          40159 2024-01-08 19:00:00 2024-07-31 06:00:00
#
#        Time of Occurrence       City  Crime Code Crime Description  \
# 0     2020-01-01 01:11:00  Ahmedabad         576    IDENTITY THEFT
# 1     2020-01-01 06:26:00    Chennai         128          HOMICIDE
# ...

# %%
df[df['Victim Age'] < 30]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 0                  1 2020-02-01 00:00:00 2020-01-01 00:00:00
# 5                  6 2020-02-01 03:00:00 2020-01-01 05:00:00
# 9                 10 2020-03-01 07:00:00 2020-01-01 09:00:00
# 11                12 2020-03-01 09:00:00 2020-01-01 11:00:00
# 18                19 2020-02-01 20:00:00 2020-01-01 18:00:00
# ...              ...                 ...                 ...
# 40137          40138                 NaT 2024-07-30 09:00:00
# 40142          40143 2024-01-08 22:00:00 2024-07-30 14:00:00
# 40145          40146                 NaT 2024-07-30 17:00:00
# 40147          40148 2024-02-08 18:00:00 2024-07-30 19:00:00
# 40158          40159 2024-01-08 19:00:00 2024-07-31 06:00:00
#
#        Time of Occurrence       City  Crime Code    Crime Description  \
# 0     2020-01-01 01:11:00  Ahmedabad         576       IDENTITY THEFT
# 5     2020-01-01 17:09:00      Delhi         442              ASSAULT
# ...

# %%
df[df['Victim Age'] > 50]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 6                  7 2020-01-01 16:00:00 2020-01-01 06:00:00
# 7                  8 2020-02-01 10:00:00 2020-01-01 07:00:00
# 10                11 2020-02-01 13:00:00 2020-01-01 10:00:00
# 14                15 2020-02-01 00:00:00 2020-01-01 14:00:00
# 15                16 2020-02-01 07:00:00 2020-01-01 15:00:00
# ...              ...                 ...                 ...
# 40152          40153 2024-02-08 11:00:00 2024-07-31 00:00:00
# 40153          40154                 NaT 2024-07-31 01:00:00
# 40155          40156 2024-01-08 16:00:00 2024-07-31 03:00:00
# 40156          40157                 NaT 2024-07-31 04:00:00
# 40157          40158 2024-02-08 03:00:00 2024-07-31 05:00:00
#
#        Time of Occurrence       City  Crime Code    Crime Description  \
# 6     2020-01-01 14:08:00    Chennai         172     VEHICLE - STOLEN
# 7     2020-02-01 06:33:00    Chennai         169       COUNTERFEITING
# ...

# %%
df[df['Weapon Used'] == "Firearm"]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 3                  4 2020-01-01 05:00:00 2020-01-01 03:00:00
# 5                  6 2020-02-01 03:00:00 2020-01-01 05:00:00
# 25                26 2020-02-01 16:00:00 2020-01-02 01:00:00
# 40                41 2020-05-01 01:00:00 2020-01-02 16:00:00
# 48                49 2020-05-01 19:00:00 2020-01-03 00:00:00
# ...              ...                 ...                 ...
# 40113          40114 2024-01-08 08:00:00 2024-07-29 09:00:00
# 40132          40133                 NaT 2024-07-30 04:00:00
# 40135          40136                 NaT 2024-07-30 07:00:00
# 40143          40144 2024-02-08 04:00:00 2024-07-30 15:00:00
# 40155          40156 2024-01-08 16:00:00 2024-07-31 03:00:00
#
#        Time of Occurrence           City  Crime Code   Crime Description  \
# 3     2020-01-01 14:46:00           Pune         170            BURGLARY
# 5     2020-01-01 17:09:00          Delhi         442             ASSAULT
# ...

# %%
df[df['City'] == "Delhi"]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 5                  6 2020-02-01 03:00:00 2020-01-01 05:00:00
# 10                11 2020-02-01 13:00:00 2020-01-01 10:00:00
# 32                33 2020-03-01 04:00:00 2020-01-02 08:00:00
# 42                43 2020-03-01 03:00:00 2020-01-02 18:00:00
# 46                47 2020-05-01 04:00:00 2020-01-02 22:00:00
# ...              ...                 ...                 ...
# 40131          40132                 NaT 2024-07-30 03:00:00
# 40134          40135                 NaT 2024-07-30 06:00:00
# 40142          40143 2024-01-08 22:00:00 2024-07-30 14:00:00
# 40146          40147 2024-02-08 09:00:00 2024-07-30 18:00:00
# 40159          40160                 NaT 2024-07-31 07:00:00
#
#        Time of Occurrence   City  Crime Code   Crime Description  Victim Age  \
# 5     2020-01-01 17:09:00  Delhi         442             ASSAULT          16
# ...

# %%
df[df['City'].isin(['Mumbai','Pune'])]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 3                  4 2020-01-01 05:00:00 2020-01-01 03:00:00
# 4                  5 2020-01-01 21:00:00 2020-01-01 04:00:00
# 8                  9 2020-04-01 03:00:00 2020-01-01 08:00:00
# 13                14 2020-02-01 22:00:00 2020-01-01 13:00:00
# 17                18 2020-04-01 02:00:00 2020-01-01 17:00:00
# ...              ...                 ...                 ...
# 40145          40146                 NaT 2024-07-30 17:00:00
# 40149          40150                 NaT 2024-07-30 21:00:00
# 40150          40151 2024-01-08 23:00:00 2024-07-30 22:00:00
# 40151          40152 2024-01-08 00:00:00 2024-07-30 23:00:00
# 40156          40157                 NaT 2024-07-31 04:00:00
#
#        Time of Occurrence    City  Crime Code    Crime Description  \
# 3     2020-01-01 14:46:00    Pune         170             BURGLARY
# 4     2020-01-01 16:51:00    Pune         421            VANDALISM
# ...

# %%
df[df['Crime Domain'] == "Violent Crime"]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 0                  1 2020-02-01 00:00:00 2020-01-01 00:00:00
# 5                  6 2020-02-01 03:00:00 2020-01-01 05:00:00
# 6                  7 2020-01-01 16:00:00 2020-01-01 06:00:00
# 11                12 2020-03-01 09:00:00 2020-01-01 11:00:00
# 13                14 2020-02-01 22:00:00 2020-01-01 13:00:00
# ...              ...                 ...                 ...
# 40146          40147 2024-02-08 09:00:00 2024-07-30 18:00:00
# 40148          40149 2024-01-08 04:00:00 2024-07-30 20:00:00
# 40157          40158 2024-02-08 03:00:00 2024-07-31 05:00:00
# 40158          40159 2024-01-08 19:00:00 2024-07-31 06:00:00
# 40159          40160                 NaT 2024-07-31 07:00:00
#
#        Time of Occurrence       City  Crime Code  Crime Description  \
# 0     2020-01-01 01:11:00  Ahmedabad         576     IDENTITY THEFT
# 5     2020-01-01 17:09:00      Delhi         442            ASSAULT
# ...

# %%
df[df['Police Deployed'] > 15]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 4                  5 2020-01-01 21:00:00 2020-01-01 04:00:00
# 5                  6 2020-02-01 03:00:00 2020-01-01 05:00:00
# 13                14 2020-02-01 22:00:00 2020-01-01 13:00:00
# 14                15 2020-02-01 00:00:00 2020-01-01 14:00:00
# 15                16 2020-02-01 07:00:00 2020-01-01 15:00:00
# ...              ...                 ...                 ...
# 40137          40138                 NaT 2024-07-30 09:00:00
# 40139          40140                 NaT 2024-07-30 11:00:00
# 40141          40142 2024-01-08 04:00:00 2024-07-30 13:00:00
# 40145          40146                 NaT 2024-07-30 17:00:00
# 40148          40149 2024-01-08 04:00:00 2024-07-30 20:00:00
#
#        Time of Occurrence       City  Crime Code Crime Description  \
# 4     2020-01-01 16:51:00       Pune         421         VANDALISM
# 5     2020-01-01 17:09:00      Delhi         442           ASSAULT
# ...

# %%
h = df[df['Victim Gender'] == 'F']

# %%
h[h['Case Closed']=="Yes"]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 3                  4 2020-01-01 05:00:00 2020-01-01 03:00:00
# 4                  5 2020-01-01 21:00:00 2020-01-01 04:00:00
# 6                  7 2020-01-01 16:00:00 2020-01-01 06:00:00
# 12                13 2020-01-01 16:00:00 2020-01-01 12:00:00
# 15                16 2020-02-01 07:00:00 2020-01-01 15:00:00
# ...              ...                 ...                 ...
# 40146          40147 2024-02-08 09:00:00 2024-07-30 18:00:00
# 40151          40152 2024-01-08 00:00:00 2024-07-30 23:00:00
# 40153          40154                 NaT 2024-07-31 01:00:00
# 40156          40157                 NaT 2024-07-31 04:00:00
# 40159          40160                 NaT 2024-07-31 07:00:00
#
#        Time of Occurrence           City  Crime Code    Crime Description  \
# 3     2020-01-01 14:46:00           Pune         170             BURGLARY
# 4     2020-01-01 16:51:00           Pune         421            VANDALISM
# ...

# %%
df['Month'] = df['Date Reported'].dt.month_name()
df['Month'].value_counts()
# Out:
# Month
# December     1386
# July         1381
# May          1374
# November     1350
# September    1339
# March        1317
# August       1300
# October      1294
# April        1291
# January      1286
# February     1280
# June         1276
# Name: count, dtype: int64

# %%
df['Year'] = df['Date Reported'].dt.year
df['Year'].value_counts()
# Out:
# Year
# 2021.0    3471
# 2022.0    3461
# 2020.0    3452
# 2023.0    3450
# 2024.0    2040
# Name: count, dtype: int64

# %%
df
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 0                  1 2020-02-01 00:00:00 2020-01-01 00:00:00
# 1                  2 2020-01-01 19:00:00 2020-01-01 01:00:00
# 2                  3 2020-02-01 05:00:00 2020-01-01 02:00:00
# 3                  4 2020-01-01 05:00:00 2020-01-01 03:00:00
# 4                  5 2020-01-01 21:00:00 2020-01-01 04:00:00
# ...              ...                 ...                 ...
# 40155          40156 2024-01-08 16:00:00 2024-07-31 03:00:00
# 40156          40157                 NaT 2024-07-31 04:00:00
# 40157          40158 2024-02-08 03:00:00 2024-07-31 05:00:00
# 40158          40159 2024-01-08 19:00:00 2024-07-31 06:00:00
# 40159          40160                 NaT 2024-07-31 07:00:00
#
#        Time of Occurrence       City  Crime Code   Crime Description  \
# 0     2020-01-01 01:11:00  Ahmedabad         576      IDENTITY THEFT
# 1     2020-01-01 06:26:00    Chennai         128            HOMICIDE
# ...

# %%
df['WeekDay'] = df['Date Reported'].dt.day_name()
df['WeekDay']
# Out:
# 0         Saturday
# 1        Wednesday
# 2         Saturday
# 3        Wednesday
# 4        Wednesday
#            ...
# 40155       Monday
# 40156          NaN
# 40157     Thursday
# 40158       Monday
# 40159          NaN
# Name: WeekDay, Length: 40160, dtype: object

# %%
df[df['WeekDay'].isin(["Sunday", "Saturday"])]
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 0                  1 2020-02-01 00:00:00 2020-01-01 00:00:00
# 2                  3 2020-02-01 05:00:00 2020-01-01 02:00:00
# 5                  6 2020-02-01 03:00:00 2020-01-01 05:00:00
# 7                  8 2020-02-01 10:00:00 2020-01-01 07:00:00
# 9                 10 2020-03-01 07:00:00 2020-01-01 09:00:00
# ...              ...                 ...                 ...
# 39687          39688 2024-12-07 17:00:00 2024-07-11 15:00:00
# 39697          39698 2024-12-07 18:00:00 2024-07-12 01:00:00
# 39700          39701 2024-12-07 16:00:00 2024-07-12 04:00:00
# 39702          39703 2024-12-07 09:00:00 2024-07-12 06:00:00
# 39707          39708 2024-12-07 21:00:00 2024-07-12 11:00:00
#
#        Time of Occurrence       City  Crime Code    Crime Description  \
# 0     2020-01-01 01:11:00  Ahmedabad         576       IDENTITY THEFT
# 2     2020-01-01 14:30:00   Ludhiana         271           KIDNAPPING
# ...

# %%
k= df[df['WeekDay'].isin(["Sunday","Saturday"])].count()

# %%
k2= df[df['WeekDay'].isin(["Monday","Tuesday","Wednesday","Thursday","Friday"])].count()

# %%
print("This is WeekEnd",k)
print("This is WeekDays",k2)
# Out:
# This is WeekEnd Report Number         4565
# Date Reported         4565
# Date of Occurrence    4565
# Time of Occurrence    4139
# City                  4565
# Crime Code            4565
# Crime Description     4565
# Victim Age            4565
# Victim Gender         4565
# Weapon Used           4565
# Crime Domain          4565
# Police Deployed       4565
# Case Closed           4565
# Date Case Closed      2272
# Time                  4139
# Month                 4565
# Year                  4565
# WeekDay               4565
# dtype: int64
# This is WeekDays Report Number         11309
# Date Reported         11309
# Date of Occurrence    11309
# Time of Occurrence    10294
# City                  11309
# Crime Code            11309
# Crime Description     11309
# Victim Age            11309
# Victim Gender         11309
# Weapon Used           11309
# Crime Domain          11309
# Police Deployed       11309
# Case Closed           11309
# Date Case Closed       5651
# ...

# %%
df['Month'].value_counts().head(1)
# Out:
# Month
# December    1386
# Name: count, dtype: int64

# %%
g=df['Date Reported']

# %%
g1 = df['Date of Occurrence']

# %%
g2 = g-g1

# %%
g2.mean()
# Out:
# Timedelta('11 days 23:34:45.296711603')

# %%
h = df['Date Case Closed']

# %%
d = h-g

# %%
d.mean()
# Out:
# Timedelta('78 days 13:58:13.676637637')

# %%
df.groupby("Month")['Crime Domain'].value_counts()
# Out:
# Month      Crime Domain
# April      Other Crime         757
#            Violent Crime       363
#            Fire Accident       115
#            Traffic Fatality     56
# August     Other Crime         735
#            Violent Crime       376
#            Fire Accident       123
#            Traffic Fatality     66
# December   Other Crime         769
#            Violent Crime       420
#            Fire Accident       139
#            Traffic Fatality     58
# February   Other Crime         714
#            Violent Crime       403
#            Fire Accident        98
#            Traffic Fatality     65
# January    Other Crime         767
#            Violent Crime       341
#            Fire Accident       108
#            Traffic Fatality     70
# July       Other Crime         802
#            Violent Crime       376
#            Fire Accident       136
#            Traffic Fatality     67
# June       Other Crime         750
#            Violent Crime       344
# ...

# %%
df.groupby("Year")['Crime Domain'].value_counts()
# Out:
# Year    Crime Domain
# 2020.0  Other Crime         1981
#         Violent Crime        988
#         Fire Accident        325
#         Traffic Fatality     158
# 2021.0  Other Crime         1971
#         Violent Crime       1020
#         Fire Accident        305
#         Traffic Fatality     175
# 2022.0  Other Crime         1953
#         Violent Crime       1002
#         Fire Accident        339
#         Traffic Fatality     167
# 2023.0  Other Crime         2013
#         Violent Crime        978
#         Fire Accident        319
#         Traffic Fatality     140
# 2024.0  Other Crime         1167
#         Violent Crime        576
#         Fire Accident        193
#         Traffic Fatality     104
# Name: count, dtype: int64

# %%
df['Time'].value_counts().head(1)
# Out:
# Time
# 13:54:00    22
# Name: count, dtype: int64

# %%
top_crime = (
    df.groupby("City")["Crime Description"]
      .agg(lambda x: x.value_counts().idxmax())
)

print(top_crime)
# Out:
# City
# Agra                         ASSAULT
# Ahmedabad                    ASSAULT
# Bangalore        PUBLIC INTOXICATION
# Bhopal                       ASSAULT
# Chennai                     HOMICIDE
# Delhi                FIREARM OFFENSE
# Faridabad             IDENTITY THEFT
# Ghaziabad          TRAFFIC VIOLATION
# Hyderabad           VEHICLE - STOLEN
# Indore               FIREARM OFFENSE
# Jaipur                COUNTERFEITING
# Kalyan             TRAFFIC VIOLATION
# Kanpur                     VANDALISM
# Kolkata                        FRAUD
# Lucknow            TRAFFIC VIOLATION
# Ludhiana                       FRAUD
# Meerut             DOMESTIC VIOLENCE
# Mumbai                SEXUAL ASSAULT
# Nagpur                       ASSAULT
# Nashik                       ASSAULT
# Patna                 SEXUAL ASSAULT
# Pune                       VANDALISM
# Rajkot                     EXTORTION
# Srinagar            VEHICLE - STOLEN
# Surat              TRAFFIC VIOLATION
# ...

# %%
common_wepon = (
    df.groupby("City")["Weapon Used"]
      .agg(lambda x: x.value_counts().idxmax())
)

common_wepon
# Out:
# City
# Agra                  Firearm
# Ahmedabad          Explosives
# Bangalore              Poison
# Bhopal                  Knife
# Chennai                 Knife
# Delhi                 Firearm
# Faridabad               Other
# Ghaziabad              Poison
# Hyderabad          Explosives
# Indore             Explosives
# Jaipur             Explosives
# Kalyan                  Knife
# Kanpur                  Other
# Kolkata          Blunt Object
# Lucknow          Blunt Object
# Ludhiana         Blunt Object
# Meerut                  Knife
# Mumbai                  Knife
# Nagpur                  Knife
# Nashik                  Other
# Patna                  Poison
# Pune                    Knife
# Rajkot                Firearm
# Srinagar           Explosives
# Surat                 Firearm
# Thane              Explosives
# Varanasi                Knife
# Vasai                  Poison
# Visakhapatnam    Blunt Object
# Name: Weapon Used, dtype: object

# %%
df.groupby("Crime Domain")['Case Closed'].value_counts()*100/ 20062
# Out:
# Crime Domain      Case Closed
# Fire Accident     No              9.650085
#                   Yes             9.415811
# Other Crime       Yes            57.252517
#                   No             57.132888
# Traffic Fatality  Yes             4.785166
#                   No              4.760243
# Violent Crime     No             28.636228
#                   Yes            28.546506
# Name: count, dtype: float64

# %%
# Kaunsi city me sabse jyada police deploy hui?
df.groupby('City')['Police Deployed'].value_counts().head(1)
# Out:
# City  Police Deployed
# Agra  8                  58
# Name: count, dtype: int64

# %%
k= df[['Police Deployed','Case Closed']]

# %%
import seaborn as sns
sns.heatmap(k.corr())
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
L= LabelEncoder()

# %%
df['Case Closed'] = L.fit_transform(df['Case Closed'])

# %%
df['Case Closed'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40160 entries, 0 to 40159
# Series name: Case Closed
# Non-Null Count  Dtype
# --------------  -----
# 40160 non-null  int64
# dtypes: int64(1)
# memory usage: 313.9 KB

# %%
'''
Victim age ko bins me divide karo:

0–18
19–30
31–45
46–60
60+
'''

bins = [0, 18, 30, 45, 60,100]
labels = ['0-18', '19-30', '31-45', '46-60', '60-100']

df['Age Group'] = pd.cut(df['Victim Age'], bins=bins, labels=labels)
df['Age Group'].value_counts().reset_index(name="Crime count")
# Out:
#   Age Group  Crime count
# 0    60-100        10924
# 1     31-45         8667
# 2     46-60         8487
# 3     19-30         6961
# 4      0-18         5121

# %%
df.groupby('Age Group')['Crime Description'].value_counts().reset_index(name="Crime count")
# Out:
# C:\Users\great\AppData\Local\Temp\ipykernel_8520\441675100.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Age Group')['Crime Description'].value_counts().reset_index(name="Crime count")
#     Age Group    Crime Description  Crime count
# 0        0-18              ROBBERY          272
# 1        0-18    TRAFFIC VIOLATION          264
# 2        0-18  PUBLIC INTOXICATION          259
# 3        0-18              ASSAULT          256
# 4        0-18                FRAUD          254
# ..        ...                  ...          ...
# 100    60-100             HOMICIDE          504
# 101    60-100           KIDNAPPING          499
# 102    60-100              ASSAULT          497
# 103    60-100      FIREARM OFFENSE          494
# 104    60-100         DRUG OFFENSE          488
# ...

# %%
'''
Pivot Table banao:

Rows = City
Columns = Crime Domain
Values = Count
    '''
k= pd.pivot_table(index='City', columns='Crime Domain', values='Report Number', aggfunc='count', fill_value=0,data=df)
k
# Out:
# Crime Domain   Fire Accident  Other Crime  Traffic Fatality  Violent Crime
# City
# Agra                      83          420                33            228
# Ahmedabad                168         1009                81            559
# Bangalore                318         2096               166           1008
# Bhopal                    66          396                31            197
# Chennai                  260         1432               110            691
# Delhi                    518         3125               198           1559
# Faridabad                 36          184                18            116
# Ghaziabad                 59          397                42            206
# Hyderabad                290         1601               135            855
# Indore                    73          380                32            214
# Jaipur                   132          857                78            412
# ...

# %%
k=df['Report Number'].count()
k2 = df['City'].value_counts().count()
k3 = df['City'].mode()[0]
k4 = df['Crime Description'].mode()[0]
k5 = df['Weapon Used'].mode()[0]
k6 = df['Victim Age'].mean()
k7 = df['Police Deployed'].mean()
f8 = df['City'].value_counts().head(5)
f9 = df['Crime Description'].value_counts().head(5)
print("Total Crimes----->",k)
print("Unique Cities----->",k2)
print("Most Common City----->",k3)
print("Most Common Crime----->",k4)
print("Most Common Weapon----->",k5)
print("Average Victim Age----->",k6)
print("Average Police Deployed----->",k7)
print("Case Closure Rate----->",v)
print("Top 5 Cities----->",f8)
print("Top 5 Crimes----->",f9)
# Out:
# Total Crimes-----> 40160
# Unique Cities-----> 29
# Most Common City-----> Delhi
# Most Common Crime-----> BURGLARY
# Most Common Weapon-----> Knife
# Average Victim Age-----> 44.49125996015936
# Average Police Deployed-----> 10.00625
# Case Closure Rate-----> 49.95517928286853
# Top 5 Cities-----> City
# Delhi        5400
# Mumbai       4415
# Bangalore    3588
# Hyderabad    2881
# Kolkata      2518
# Name: count, dtype: int64
# Top 5 Crimes-----> Crime Description
# BURGLARY             1980
# VANDALISM            1975
# FRAUD                1965
# DOMESTIC VIOLENCE    1932
# FIREARM OFFENSE      1931
# Name: count, dtype: int64

# %%
k8 = df[df['Case Closed']==1]
k8
# Out:
#        Report Number       Date Reported  Date of Occurrence  \
# 3                  4 2020-01-01 05:00:00 2020-01-01 03:00:00
# 4                  5 2020-01-01 21:00:00 2020-01-01 04:00:00
# 5                  6 2020-02-01 03:00:00 2020-01-01 05:00:00
# 6                  7 2020-01-01 16:00:00 2020-01-01 06:00:00
# 10                11 2020-02-01 13:00:00 2020-01-01 10:00:00
# ...              ...                 ...                 ...
# 40149          40150                 NaT 2024-07-30 21:00:00
# 40151          40152 2024-01-08 00:00:00 2024-07-30 23:00:00
# 40153          40154                 NaT 2024-07-31 01:00:00
# 40156          40157                 NaT 2024-07-31 04:00:00
# 40159          40160                 NaT 2024-07-31 07:00:00
#
#        Time of Occurrence     City  Crime Code    Crime Description  \
# 3     2020-01-01 14:46:00     Pune         170             BURGLARY
# 4     2020-01-01 16:51:00     Pune         421            VANDALISM
# ...

# %%
l = k8.count()[0]
l
# Out:
# C:\Users\great\AppData\Local\Temp\ipykernel_8520\3530031071.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l = k8.count()[0]
# np.int64(20062)

# %%
g = df['Case Closed'].count()
g
# Out:
# np.int64(40160)

# %%
v=  l/g*100
v
# Out:
# np.float64(49.95517928286853)
